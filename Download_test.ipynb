# %%
import load_data
import pdb
data = load_data.load_FragPipe('June_noMBR_FP')
# Out:
# data/June_noMBR_FP.tsv

# %%
data
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                    1108218.50                    1451057.60
# A0AVT1                         536195.10                     711075.70
# A0FGR8                              0.00                          0.00
# A6NHR9                              0.00                          0.00
# A8MWD9                         552843.06                    1057689.60
# ...                                  ...                           ...
# Q13057                              0.00                          0.00
# P51884                              0.00                          0.00
# Q5SXH7                         248706.78                     461372.84
# Q9BWT6                              0.00                    2322967.80
# Q9NZT2                              0.00                          0.00
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# ...
