# %% [markdown]
# # Show how to use methods in load_data.py

# %% [markdown]
# Begin by importing <code>load_data</code>, which contains the methods to interface with the data files.

# %%
import load_data

# %% [markdown]
# Show how to use the functions to access the dataframes. Here we work with quant tables from MaxQuant or FragPipe.

# %%
df = load_data.load_max_quant()
df
# Out:
#                       Intensity 1_B_C10  Intensity 1_B_C11  Intensity 1_B_C12  \
# Protein IDs
# P0DPI2;A0A0B4J2D5                265300             248290            1878900
# A0AVT1                                0                  0             440250
# A6NHQ2                           126410                  0                  0
# A6NI72;P14598;A8MVU1            1246500            1821600            3189500
# P62308;A8MWD9                         0             305850                  0
# ...                                 ...                ...                ...
# Q9Y5L4                                0                  0             237520
# Q9Y5S9                           766910             415980             458400
# Q9Y5X3                           682760             748590            1265600
# Q9Y6C9                                0                  0             311590
# Q9Y6N5                           594210             121830             440970
#
# ...

# %%
df2 = load_data.load_FragPipe()
df2
# Out:
#             Subject1_B_cells_June_C_10 Total Intensity  \
# Protein ID
# A0A0B4J2D5                                 1206607.500
# A0AVT1                                      584806.900
# A0FGR8                                           0.000
# A6NHR9                                      655176.100
# A8MWD9                                      696141.440
# ...                                                ...
# P43490                                        7249.320
# P24158                                           0.000
# Q8IYJ3                                           0.000
# Q8TD55                                       16469.553
# Q9BZF1                                           0.000
#
#             Subject1_B_cells_June_C_11 Total Intensity  \
# Protein ID
# A0A0B4J2D5                                   1882145.4
# A0AVT1                                        872883.0
# A0FGR8                                             0.0
# ...

# %% [markdown]
# Note the differences in names, however identifying the Subject 1 B or T cells as those containing "1_B_" or "1_T_" is consistent.

# %% [markdown]
# The columns are the samples. Each row is a protein as identified in each sample.
